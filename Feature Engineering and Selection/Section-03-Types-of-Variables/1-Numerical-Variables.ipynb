# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data = pd.read_csv('/workspaces/30---Days-Machine-Learning/Feature Engineering and Selection/Datasets/loan.csv')
data.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12
# ...

# %%
data.dtypes
# Out:
# customer_id                 int64
# disbursed_amount          float64
# interest                  float64
# market                        str
# employment                    str
# time_employed                 str
# householder                   str
# income                    float64
# date_issued                   str
# target                      int64
# loan_purpose                  str
# number_open_accounts      float64
# date_last_payment             str
# number_credit_lines_12    float64
# dtype: object

# %% [markdown]
# ## Continuous variables

# %%
data['disbursed_amount'].head()
# Out:
# 0    23201.5
# 1     7425.0
# 2    11150.0
# 3     7600.0
# 4    31960.0
# Name: disbursed_amount, dtype: float64

# %%
# Let's make a histogram to get familiar with the
# variable distribution.

fig = data['disbursed_amount'].hist(bins=50)

fig.set_title('Requested loan amount')
fig.set_xlabel('Loan amount')
fig.set_ylabel('Number of loans')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Let's make a histogram to get familiar with the
#       2 # variable distribution.
#       3
# ----> 4 fig = data['disbursed_amount'].hist(bins=50)
#       5
#       6 fig.set_title('Requested loan amount')
#       7 fig.set_xlabel('Loan amount')
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/plotting/_core.py:131, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      49 @set_module("pandas.plotting")
#      50 def hist_series(
#      51     self: Series,
#    (...)     63     **kwargs,
#      64 ):
#      65     """
#      66     Draw histogram of the input series using matplotlib.
#      67
#    (...)    129         >>> hist = ser.groupby(level=0).hist()
#     130     """
# ...
